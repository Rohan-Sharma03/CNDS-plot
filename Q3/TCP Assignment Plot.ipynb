# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df0 = pd.read_csv("Node0WaitingTime.csv")
df1 = pd.read_csv("Node1WaitingTime.csv")
df2 = pd.read_csv("Node2WaitingTime.csv")
df3 = pd.read_csv("NodesQueueSize.csv")
df4 = pd.read_csv("Node0QueueSize.csv")
df5 = pd.read_csv("Node1QueueSize.csv")
df6 = pd.read_csv("Node2QueueSize.csv")

# %%
df0
# Out:
#          Time  Waiting Time
# 0     1.00000       0.00000
# 1     1.40015       0.00000
# 2     1.40018       0.00003
# 3     1.40050       0.00035
# 4     1.40081       0.00066
# ...       ...           ...
# 3258  9.96798       0.00031
# 3259  9.96861       0.00000
# 3260  9.96892       0.00031
# 3261  9.96955       0.00000
# 3262  9.96987       0.00032
#
# [3263 rows x 2 columns]

# %%
df0.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 0',title="Waiting Time v/s Time for node 0",ylabel="Waiting Time")
plt.show()

# %%
df1.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 1',title="Waiting Time v/s Time for node 1",ylabel="Waiting Time")
plt.show()

# %%
df2.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 2', title="Waiting Time v/s Time for node 2",ylabel="Waiting Time")
plt.show()

# %%
df3.plot(x='Time', y='QueueSize', label='Queue size of all nodes at particular time' ,title="Queue Size v/s Time",ylabel="Size")
plt.show()

# %%
df4.plot(x='Time', y='QueueSize', label='Queue size at Nodes 0',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()

# %%
df5.plot(x='Time', y='QueueSize', label='Queue size at Nodes 1',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()

# %%
df6.plot(x='Time', y='QueueSize', label='Queue size at Nodes 2',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()
