# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df0 = pd.read_csv("cwndQ1Q2.csv",index_col=0)
df1 = pd.read_csv("cwndQ1Q3.csv",index_col=0)

# %%
df0.plot(ylabel="Congestion Window Size", title = "Congestion window of Q1 and Q2")
# Out:
# <Axes: title={'center': 'Congestion window of Q1 and Q2'}, xlabel='Time ', ylabel='Congestion Window Size'>

# %%
df1.plot(ylabel="Congestion Window Size", title = "Congestion window of Q1 and Q3")
# Out:
# <Axes: title={'center': 'Congestion window of Q1 and Q3'}, xlabel='Time ', ylabel='Congestion Window Size'>

# %%
import matplotlib.pyplot as plt

# Generate some example data
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 30, 40, 50]
y2 = [2, 4, 6, 8, 10]
y3 = [100, 80, 60, 40, 20]

# Create a figure and axis
fig, ax1 = plt.subplots()

# Plot the first y-axis data
ax1.plot(x, y1, 'b-', label='Y1')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y1', color='b')
ax1.tick_params('y', colors='b')

# Create a second y-axis
ax2 = ax1.twinx()

# Plot the second y-axis data
ax2.plot(x, y2, 'r--', label='Y2')
ax2.set_ylabel('Y2', color='r')
ax2.tick_params('y', colors='r')

# Add legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='lower right')

# Show the plot
plt.show()
