# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df0 = pd.read_csv("Node0valuesWaitingTime.csv")
df1 = pd.read_csv("Node1valuesWaitingTime.csv")
df2 = pd.read_csv("Node2valuesWaitingTime.csv")
df3 = pd.read_csv("NodesQueueSize.csv")
df4 = pd.read_csv("Node0QueueSize.csv")
df5 = pd.read_csv("Node1QueueSize.csv")
df6 = pd.read_csv("Node2QueueSize.csv")

# %%
df0
# Out:
#          Time  Waiting Time
# 0     1.00000       0.00000
# 1     1.22022       0.00000
# 2     1.22025       0.00003
# 3     1.22056       0.00034
# 4     1.22087       0.00065
# ...       ...           ...
# 5385  9.89512       0.00032
# 5386  9.89638       0.00000
# 5387  9.89669       0.00031
# 5388  9.89795       0.00000
# 5389  9.89827       0.00032
#
# [5390 rows x 2 columns]

# %%
df0.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 0')
plt.show()

# %%
df1.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 1')
plt.show()

# %%
df2.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 2')
plt.show()

# %%
df3.plot(x='Time', y='QueueSize', label='Queue size of all nodes at particular time ')
plt.show()

# %%
df4.plot(x='Time', y='QueueSize', label='Queue size at Nodes 0')
plt.show()

# %%
df5.plot(x='Time', y='QueueSize', label='Queue size at Nodes 1')
plt.show()

# %%
df6.plot(x='Time', y='QueueSize', label='Queue size at Nodes 2')
plt.show()
